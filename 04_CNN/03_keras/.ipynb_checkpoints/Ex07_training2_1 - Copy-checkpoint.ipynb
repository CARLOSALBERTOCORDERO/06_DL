# %%
# https://www.youtube.com/watch?v=aQaZMC9-Jok

import sys
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.models import Sequential  # Can not be moved
from tensorflow.keras.models import load_model
from keras.layers import Conv2D, MaxPooling2D  # Can not be moved
from keras.layers import Activation, Dropout, Flatten, Dense # Can not be moved
from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing import image
import numpy as np
from os import listdir
from os.path import isfile, join

from keras import optimizers

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
currentPath = os.getcwd()

# %%
train_data = currentPath + os.sep + "data" + os.sep + "data" + os.sep + "train"
test_data = currentPath + os.sep + "data" + os.sep + "data" + os.sep + "test"

# Número de iteraciones sobre todo el dataset de entrenamiento
epochs = 20

# Dimensiones de las imágenes para procesar
n_H, n_W = 100, 100

# Utilizaremos mini-batch
batch_size = 32

# Número de iteraciones que vamos a procesar la información en cada epoca (entrenamiento)
train_samples = 1000

# Número de iteraciones que vamos a procesar la información en cada epoca (validación)
validation_samples = 200

# Definamos la tasa de aprendizaje
learning_rate = 0.05

# Número de clases
class_num = 3

# Estructura de la red neuronal convolucionales
filter_conv1 = 32
size_filter1 = (3,3)

filter_conv2 = 64
size_filter2 = (2,2)

#Usaremos un Max Pooling
size_pool = (2,2)


# 1. Antes de comenzar con el modelo, vamos a preprocesar las imágenes
train_datagen = ImageDataGenerator(
    rescale = 1./255,          # Normalizar los valores de los pixeles
    shear_range= 0.3,           # Rango del ángulo que podemos inclinar nuestras imágenes
    zoom_range = 0.3,            # Rango del zoom que podemos hacer a nuestras imágenes
    horizontal_flip = True       # Invierte imágenes
)

test_datagen = ImageDataGenerator(
    rescale = 1./255           # Normalizar los valores de los pixeles
)

# Accede al directorio, preprocesa las imágenes y organiza en mini-batchs
train_generator = train_datagen.flow_from_directory(
    train_data,
    target_size = (n_H, n_W),             # Tamaño de las imágenes
    batch_size = batch_size,              # Tamaño del mini-batch
    class_mode = 'categorical'            # Modelo para clasificación
)

# Accede al directorio, preprocesa las imágenes y organiza en mini-batchs
validation_generator = test_datagen.flow_from_directory(
    test_data,
    target_size = (n_H, n_W),
    batch_size = batch_size,
    class_mode = 'categorical'
)
# Out:
# Found 999 images belonging to 3 classes.
# Found 2043 images belonging to 3 classes.

# %%
# Check for TensorFlow or Thieno
if K.image_data_format() == "channels_first":
    input_shape = (3, n_W, n_H)
else:
    input_shape = (n_W, n_H, 3)

# %%
# 2. Crear la ConvNet
def createModel():
    model = Sequential()
    model.add(Conv2D(filter_conv1, size_filter1, padding="same", input_shape=(n_H, n_W,3), activation="relu"))
    model.add(MaxPooling2D(pool_size=size_pool))
    model.add(Conv2D(filter_conv2, size_filter2, padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=size_pool))
    model.add(Flatten())
    model.add(Dense(255, activation=None))
    model.add(Dropout(0.5))
    model.add(Dense(class_num, activation='softmax'))

    return model

# %%
print(train_generator.class_indices)
imgs, labels = next(train_generator)
# Out:
# {'cat': 0, 'dog': 1, 'gorilla': 2}

# %%
def imshow(image_RGB):
    image_0_2_1 = image_RGB
    print(image_0_2_1.shape)
    plt.imshow(image_0_2_1)

# %%
image_batch, label_batch = train_generator.next()

print(len(image_batch))
for index in range(0, len(image_batch)):
    image = image_batch[index]
    print(label_batch[index])
    imshow(image)
# Out:
# 32
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [1. 0. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)
# [0. 1. 0.]
# (100, 100, 3)

# %%
model = createModel()
model.compile(loss='categorical_crossentropy', 
              optimizer=optimizers.Adam(learning_rate),  
              metrics=['accuracy'])

# %%
history = model.fit_generator(
    train_generator, 
    steps_per_epoch=train_samples, 
    epochs=epochs, 
    validation_data = validation_generator, 
    validation_steps=validation_samples)
# Out:
# Epoch 1/20
#  172/1000 [====>.........................] - ETA: 1:03 - loss: 0.9129 - accuracy: 0.4934

# %%
# Definamos donde queremos guardar nuestro modelo y los pesos
dirPath=currentPath + os.sep + "model" + os.sep

# %%
if not os.path.exists(dirPath):
    os.mkdir(dirPath)
    
model.save(dirPath + "model.h5")
model.save_weights(dirPath + "weights.h5")

# %%
# Lets plot the results
print(history.history.keys())
# history accuracy
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("model accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %%
# history accuracy
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %%
# Evaluate
model = createModel()
model.load_weights(dirPath + os.sep + "weights.h5")

img_path = test_data + os.sep + "gorilla" + os.sep + "18.jpeg"
img = load_img(img_path, target_size=(n_H, n_W))

imgArray = img_to_array(img)
# Update to 0-1 format
imgArray = imgArray / 255.0
print(imgArray.shape)
plt.imshow(imgArray)
# The modelexspect batches then lets do a batch of 1 
imgArray = np.expand_dims(imgArray, axis=0)

# Predict
classList = os.listdir(test_data)
prediction = model.predict(imgArray)
print(prediction)
prediction = model.predict_classes(imgArray)
print(classList[prediction[0]])
# Out:
# (100, 100, 3)
# [[0.387083   0.60709023 0.00582673]]
# dog

# %%
# Lets predict the gorillas
gorillapath = test_data + os.sep + "dog" + os.sep
imagesPredict = [f for f in listdir(gorillapath) if isfile(join(gorillapath,f))]
# print(imagesPredict)

for file in imagesPredict:
    img = load_img(gorillapath + file, target_size=( n_W, n_H))
    tensorImage = img_to_array(img)
    tensorImage = np.expand_dims(tensorImage, axis=0)
    gorillaPrediction = model.predict_classes(tensorImage, batch_size = 1)
    print("file "+ file + " is: " + classList[gorillaPrediction[0]])
# Out:
# file dog.4001.jpg is: cat
# file dog.4002.jpg is: cat
# file dog.4003.jpg is: gorilla
# file dog.4004.jpg is: cat
# file dog.4005.jpg is: cat
# file dog.4006.jpg is: cat
# file dog.4007.jpg is: cat
# file dog.4008.jpg is: gorilla
# file dog.4009.jpg is: cat
# file dog.4010.jpg is: cat
# file dog.4011.jpg is: cat
# file dog.4012.jpg is: cat
# file dog.4013.jpg is: cat
# file dog.4014.jpg is: cat
# file dog.4015.jpg is: cat
# file dog.4016.jpg is: gorilla
# file dog.4017.jpg is: gorilla
# file dog.4018.jpg is: cat
# file dog.4019.jpg is: cat
# file dog.4020.jpg is: cat
# file dog.4021.jpg is: cat
# file dog.4022.jpg is: cat
# file dog.4023.jpg is: cat
# file dog.4024.jpg is: cat
# file dog.4025.jpg is: cat
# file dog.4026.jpg is: gorilla
# file dog.4027.jpg is: cat
# file dog.4028.jpg is: cat
# file dog.4029.jpg is: cat
# file dog.4030.jpg is: cat
# file dog.4031.jpg is: gorilla
# file dog.4032.jpg is: cat
# file dog.4033.jpg is: gorilla
# file dog.4034.jpg is: cat
# file dog.4035.jpg is: cat
# file dog.4036.jpg is: cat
# file dog.4037.jpg is: gorilla
# file dog.4038.jpg is: cat
# file dog.4039.jpg is: cat
# file dog.4040.jpg is: cat
# file dog.4041.jpg is: cat
# file dog.4042.jpg is: gorilla
# file dog.4043.jpg is: cat
# file dog.4044.jpg is: cat
# file dog.4045.jpg is: cat
# file dog.4046.jpg is: cat
# file dog.4047.jpg is: cat
# file dog.4048.jpg is: cat
# file dog.4049.jpg is: cat
# file dog.4050.jpg is: cat
# file dog.4051.jpg is: cat
# file dog.4052.jpg is: cat
# file dog.4053.jpg is: cat
# file dog.4054.jpg is: cat
# file dog.4055.jpg is: cat
# file dog.4056.jpg is: cat
# file dog.4057.jpg is: cat
# file dog.4058.jpg is: gorilla
# file dog.4059.jpg is: cat
# file dog.4060.jpg is: gorilla
# file dog.4061.jpg is: cat
# file dog.4062.jpg is: cat
# file dog.4063.jpg is: cat
# file dog.4064.jpg is: cat
# file dog.4065.jpg is: gorilla
# file dog.4066.jpg is: gorilla
# file dog.4067.jpg is: cat
# file dog.4068.jpg is: gorilla
# file dog.4069.jpg is: cat
# file dog.4070.jpg is: cat
# file dog.4071.jpg is: cat
# file dog.4072.jpg is: cat
# file dog.4073.jpg is: cat
# file dog.4074.jpg is: cat
# file dog.4075.jpg is: cat
# file dog.4076.jpg is: cat
# file dog.4077.jpg is: cat
# file dog.4078.jpg is: cat
# file dog.4079.jpg is: cat
# file dog.4080.jpg is: cat
# file dog.4081.jpg is: cat
# file dog.4082.jpg is: gorilla
# file dog.4083.jpg is: cat
# file dog.4084.jpg is: cat
# file dog.4085.jpg is: cat
# file dog.4086.jpg is: gorilla
# file dog.4087.jpg is: cat
# file dog.4088.jpg is: cat
# file dog.4089.jpg is: gorilla
# file dog.4090.jpg is: cat
# file dog.4091.jpg is: cat
# file dog.4092.jpg is: cat
# file dog.4093.jpg is: cat
# file dog.4094.jpg is: cat
# file dog.4095.jpg is: cat
# file dog.4096.jpg is: cat
# file dog.4097.jpg is: cat
# file dog.4098.jpg is: cat
# file dog.4099.jpg is: cat
# file dog.4100.jpg is: cat
# file dog.4101.jpg is: cat
# file dog.4102.jpg is: cat
# file dog.4103.jpg is: cat
# file dog.4104.jpg is: cat
# file dog.4105.jpg is: cat
# file dog.4106.jpg is: gorilla
# file dog.4107.jpg is: cat
# file dog.4108.jpg is: gorilla
# file dog.4109.jpg is: cat
# file dog.4110.jpg is: cat
# file dog.4111.jpg is: cat
# file dog.4112.jpg is: cat
# file dog.4113.jpg is: cat
# file dog.4114.jpg is: cat
# file dog.4115.jpg is: cat
# file dog.4116.jpg is: cat
# file dog.4117.jpg is: cat
# file dog.4118.jpg is: gorilla
# file dog.4119.jpg is: cat
# file dog.4120.jpg is: cat
# file dog.4121.jpg is: cat
# file dog.4122.jpg is: cat
# file dog.4123.jpg is: cat
# file dog.4124.jpg is: cat
# file dog.4125.jpg is: cat
# file dog.4126.jpg is: cat
# file dog.4127.jpg is: cat
# file dog.4128.jpg is: cat
# file dog.4129.jpg is: cat
# file dog.4130.jpg is: cat
# file dog.4131.jpg is: gorilla
# file dog.4132.jpg is: cat
# file dog.4133.jpg is: cat
# file dog.4134.jpg is: cat
# file dog.4135.jpg is: cat
# file dog.4136.jpg is: cat
# file dog.4137.jpg is: cat
# file dog.4138.jpg is: cat
# file dog.4139.jpg is: cat
# file dog.4140.jpg is: cat
# file dog.4141.jpg is: cat
# file dog.4142.jpg is: cat
# file dog.4143.jpg is: gorilla
# file dog.4144.jpg is: cat
# file dog.4145.jpg is: cat
# file dog.4146.jpg is: cat
# file dog.4147.jpg is: cat
# file dog.4148.jpg is: gorilla
# file dog.4149.jpg is: cat
# file dog.4150.jpg is: cat
# file dog.4151.jpg is: cat
# file dog.4152.jpg is: cat
# file dog.4153.jpg is: cat
# file dog.4154.jpg is: cat
# file dog.4155.jpg is: gorilla
# file dog.4156.jpg is: cat
# file dog.4157.jpg is: cat
# file dog.4158.jpg is: cat
# file dog.4159(1).jpg is: cat
# file dog.4159.jpg is: cat
# file dog.4160.jpg is: cat
# file dog.4161.jpg is: cat
# file dog.4162.jpg is: cat
# file dog.4163.jpg is: cat
# file dog.4164.jpg is: cat
# file dog.4165(1).jpg is: cat
# file dog.4165.jpg is: cat
# file dog.4166.jpg is: cat
# file dog.4167.jpg is: cat
# file dog.4168.jpg is: cat
# file dog.4169.jpg is: cat
# file dog.4170.jpg is: cat
# file dog.4171(1).jpg is: cat
# file dog.4171.jpg is: cat
# file dog.4172.jpg is: gorilla
# file dog.4173.jpg is: gorilla
# file dog.4174.jpg is: cat
# file dog.4175.jpg is: cat
# file dog.4176.jpg is: cat
# file dog.4177.jpg is: cat
# file dog.4178.jpg is: cat
# file dog.4179.jpg is: cat
# file dog.4180.jpg is: cat
# file dog.4181.jpg is: cat
# file dog.4182.jpg is: cat
# file dog.4183.jpg is: cat
# file dog.4184.jpg is: cat
# file dog.4185.jpg is: cat
# file dog.4186.jpg is: cat
# file dog.4187.jpg is: cat
# file dog.4188.jpg is: cat
# file dog.4189.jpg is: cat
# file dog.4190.jpg is: cat
# file dog.4191.jpg is: cat
# file dog.4192.jpg is: gorilla
# file dog.4193.jpg is: gorilla
# file dog.4194.jpg is: cat
# file dog.4195.jpg is: gorilla
# file dog.4196.jpg is: cat
# file dog.4197.jpg is: cat
# file dog.4198.jpg is: cat
# file dog.4199.jpg is: cat
# file dog.4200.jpg is: cat
# file dog.4201.jpg is: cat
# file dog.4202.jpg is: cat
# file dog.4203.jpg is: cat
# file dog.4204.jpg is: cat
# file dog.4205(1).jpg is: cat
# file dog.4205.jpg is: cat
# file dog.4206.jpg is: cat
# file dog.4207.jpg is: cat
# file dog.4208.jpg is: cat
# file dog.4209.jpg is: cat
# file dog.4210.jpg is: cat
# file dog.4211.jpg is: cat
# file dog.4212.jpg is: cat
# file dog.4213.jpg is: cat
# file dog.4214.jpg is: gorilla
# file dog.4215.jpg is: cat
# file dog.4216.jpg is: cat
# file dog.4217.jpg is: cat
# file dog.4218.jpg is: cat
# file dog.4219.jpg is: gorilla
# file dog.4220.jpg is: cat
# file dog.4221.jpg is: cat
# file dog.4222.jpg is: cat
# file dog.4223.jpg is: gorilla
# file dog.4224.jpg is: cat
# file dog.4225.jpg is: cat
# file dog.4226.jpg is: cat
# file dog.4227.jpg is: cat
# file dog.4228.jpg is: cat
# file dog.4229.jpg is: cat
# file dog.4230.jpg is: cat
# file dog.4231.jpg is: cat
# file dog.4232.jpg is: cat
# file dog.4233.jpg is: cat
# file dog.4234.jpg is: cat
# file dog.4235.jpg is: gorilla
# file dog.4236.jpg is: cat
# file dog.4237.jpg is: cat
# file dog.4238.jpg is: cat
# file dog.4239.jpg is: cat
# file dog.4240.jpg is: cat
# file dog.4241.jpg is: cat
# file dog.4242.jpg is: cat
# file dog.4243.jpg is: cat
# file dog.4244.jpg is: cat
# file dog.4245.jpg is: cat
# file dog.4246.jpg is: cat
# file dog.4247.jpg is: cat
# file dog.4248.jpg is: cat
# file dog.4249.jpg is: cat
# file dog.4250.jpg is: cat
# file dog.4251.jpg is: cat
# file dog.4252.jpg is: cat
# file dog.4253.jpg is: cat
# file dog.4254.jpg is: cat
# file dog.4255.jpg is: cat
# file dog.4256.jpg is: gorilla
# file dog.4257.jpg is: cat
# file dog.4258.jpg is: cat
# file dog.4259.jpg is: cat
# file dog.4260.jpg is: cat
# file dog.4261.jpg is: cat
# file dog.4262.jpg is: cat
# file dog.4263.jpg is: cat
# file dog.4264.jpg is: cat
# file dog.4265.jpg is: cat
# file dog.4266.jpg is: gorilla
# file dog.4267.jpg is: cat
# file dog.4268.jpg is: cat
# file dog.4269.jpg is: cat
# file dog.4270.jpg is: cat
# file dog.4271.jpg is: cat
# file dog.4272.jpg is: cat
# file dog.4273.jpg is: cat
# file dog.4274.jpg is: cat
# file dog.4275.jpg is: cat
# file dog.4276.jpg is: cat
# file dog.4277.jpg is: cat
# file dog.4278.jpg is: cat
# file dog.4279.jpg is: cat
# file dog.4280.jpg is: cat
# file dog.4281.jpg is: cat
# file dog.4282.jpg is: cat
# file dog.4283.jpg is: cat
# file dog.4284.jpg is: cat
# file dog.4285.jpg is: cat
# file dog.4286.jpg is: cat
# file dog.4287.jpg is: cat
# file dog.4288.jpg is: cat
# file dog.4289.jpg is: cat
# file dog.4290.jpg is: cat
# file dog.4291.jpg is: cat
# file dog.4292.jpg is: cat
# file dog.4293.jpg is: cat
# file dog.4294.jpg is: cat
# file dog.4295.jpg is: cat
# file dog.4296.jpg is: cat
# file dog.4297.jpg is: cat
# file dog.4298.jpg is: cat
# file dog.4299.jpg is: cat
# file dog.4300.jpg is: cat
# file dog.4301.jpg is: cat
# file dog.4302.jpg is: cat
# file dog.4303.jpg is: cat
# file dog.4304.jpg is: cat
# file dog.4305.jpg is: cat
# file dog.4306.jpg is: cat
# file dog.4307.jpg is: cat
# file dog.4308.jpg is: cat
# file dog.4309.jpg is: cat
# file dog.4310.jpg is: cat
# file dog.4311.jpg is: cat
# file dog.4312.jpg is: cat
# file dog.4313.jpg is: cat
# file dog.4314.jpg is: cat
# file dog.4315.jpg is: cat
# file dog.4316.jpg is: cat
# file dog.4317.jpg is: cat
# file dog.4318.jpg is: cat
# file dog.4319.jpg is: cat
# file dog.4320.jpg is: cat
# file dog.4321.jpg is: cat
# file dog.4322.jpg is: cat
# file dog.4323.jpg is: cat
# file dog.4324.jpg is: cat
# file dog.4325.jpg is: gorilla
# file dog.4326.jpg is: cat
# file dog.4327.jpg is: cat
# file dog.4328.jpg is: cat
# file dog.4329.jpg is: cat
# file dog.4330.jpg is: cat
# file dog.4331.jpg is: cat
# file dog.4332.jpg is: gorilla
# file dog.4333.jpg is: cat
# file dog.4334.jpg is: cat
# file dog.4335.jpg is: cat
# file dog.4336.jpg is: cat
# file dog.4337.jpg is: cat
# file dog.4338.jpg is: cat
# file dog.4339.jpg is: cat
# file dog.4340.jpg is: cat
# file dog.4341.jpg is: cat
# file dog.4342.jpg is: cat
# file dog.4343.jpg is: cat
# file dog.4344.jpg is: cat
# file dog.4345.jpg is: cat
# file dog.4346.jpg is: cat
# file dog.4347.jpg is: cat
# file dog.4348.jpg is: cat
# file dog.4349.jpg is: cat
# file dog.4350.jpg is: cat
# file dog.4351.jpg is: cat
# file dog.4352.jpg is: cat
# file dog.4353.jpg is: cat
# file dog.4354.jpg is: cat
# file dog.4355.jpg is: cat
# file dog.4356.jpg is: cat
# file dog.4357.jpg is: cat
# file dog.4358.jpg is: cat
# file dog.4359.jpg is: gorilla
# file dog.4360.jpg is: cat
# file dog.4361.jpg is: cat
# file dog.4362.jpg is: cat
# file dog.4363.jpg is: cat
# file dog.4364.jpg is: cat
# file dog.4365.jpg is: cat
# file dog.4366.jpg is: gorilla
# file dog.4367.jpg is: cat
# file dog.4368.jpg is: cat
# file dog.4369.jpg is: cat
# file dog.4370.jpg is: cat
# file dog.4371.jpg is: cat
# file dog.4372.jpg is: cat
# file dog.4373(1).jpg is: cat
# file dog.4373.jpg is: cat
# file dog.4374.jpg is: cat
# file dog.4375.jpg is: cat
# file dog.4376.jpg is: cat
# file dog.4377.jpg is: cat
# file dog.4378.jpg is: cat
# file dog.4379.jpg is: cat
# file dog.4380.jpg is: cat
# file dog.4381.jpg is: cat
# file dog.4382.jpg is: cat
# file dog.4383.jpg is: cat
# file dog.4384.jpg is: cat
# file dog.4385.jpg is: cat
# file dog.4386.jpg is: cat
# file dog.4387.jpg is: cat
# file dog.4388.jpg is: cat
# file dog.4389.jpg is: cat
# file dog.4390.jpg is: cat
# file dog.4391.jpg is: cat
# file dog.4392.jpg is: cat
# file dog.4393.jpg is: cat
# file dog.4394.jpg is: cat
# file dog.4395.jpg is: cat
# file dog.4396.jpg is: cat
# file dog.4397.jpg is: cat
# file dog.4398.jpg is: cat
# file dog.4399.jpg is: cat
# file dog.4400.jpg is: cat
# file dog.4401.jpg is: cat
# file dog.4402.jpg is: cat
# file dog.4403.jpg is: cat
# file dog.4404.jpg is: cat
# file dog.4405.jpg is: cat
# file dog.4406.jpg is: cat
# file dog.4407.jpg is: cat
# file dog.4408.jpg is: cat
# file dog.4409.jpg is: cat
# file dog.4410.jpg is: cat
# file dog.4411.jpg is: cat
# file dog.4412.jpg is: cat
# file dog.4413.jpg is: cat
# file dog.4414.jpg is: cat
# file dog.4415.jpg is: cat
# file dog.4416.jpg is: cat
# file dog.4417.jpg is: cat
# file dog.4418.jpg is: gorilla
# file dog.4419.jpg is: cat
# file dog.4420.jpg is: cat
# file dog.4421.jpg is: cat
# file dog.4422.jpg is: cat
# file dog.4423.jpg is: cat
# file dog.4424.jpg is: cat
# file dog.4425.jpg is: cat
# file dog.4426.jpg is: cat
# file dog.4427.jpg is: cat
# file dog.4428.jpg is: cat
# file dog.4429(1).jpg is: cat
# file dog.4429.jpg is: cat
# file dog.4430.jpg is: cat
# file dog.4431.jpg is: cat
# file dog.4432.jpg is: cat
# file dog.4433.jpg is: cat
# file dog.4434.jpg is: cat
# file dog.4435.jpg is: gorilla
# file dog.4436.jpg is: cat
# file dog.4437.jpg is: cat
# file dog.4438.jpg is: cat
# file dog.4439.jpg is: cat
# file dog.4440.jpg is: gorilla
# file dog.4441.jpg is: cat
# file dog.4442.jpg is: cat
# file dog.4443.jpg is: cat
# file dog.4444.jpg is: cat
# file dog.4445.jpg is: cat
# file dog.4446.jpg is: cat
# file dog.4447.jpg is: cat
# file dog.4448.jpg is: cat
# file dog.4449.jpg is: cat
# file dog.4450.jpg is: cat
# file dog.4451.jpg is: cat
# file dog.4452.jpg is: cat
# file dog.4453.jpg is: gorilla
# file dog.4454.jpg is: cat
# file dog.4455.jpg is: gorilla
# file dog.4456.jpg is: cat
# file dog.4457.jpg is: cat
# file dog.4458.jpg is: cat
# file dog.4459.jpg is: cat
# file dog.4460.jpg is: cat
# file dog.4461.jpg is: cat
# file dog.4462.jpg is: cat
# file dog.4463.jpg is: gorilla
# file dog.4464.jpg is: cat
# file dog.4465.jpg is: cat
# file dog.4466.jpg is: cat
# file dog.4467.jpg is: cat
# file dog.4468.jpg is: cat
# file dog.4469.jpg is: cat
# file dog.4470.jpg is: cat
# file dog.4471.jpg is: cat
# file dog.4472.jpg is: cat
# file dog.4473.jpg is: cat
# file dog.4474.jpg is: cat
# file dog.4475.jpg is: gorilla
# file dog.4476.jpg is: cat
# file dog.4477.jpg is: cat
# file dog.4478.jpg is: cat
# file dog.4479.jpg is: cat
# file dog.4480.jpg is: cat
# file dog.4481.jpg is: cat
# file dog.4482.jpg is: cat
# file dog.4483.jpg is: gorilla
# file dog.4484.jpg is: cat
# file dog.4485.jpg is: cat
# file dog.4486.jpg is: cat
# file dog.4487.jpg is: cat
# file dog.4488.jpg is: cat
# file dog.4489.jpg is: cat
# file dog.4490.jpg is: cat
# file dog.4491.jpg is: cat
# file dog.4492.jpg is: cat
# file dog.4493.jpg is: cat
# file dog.4494.jpg is: cat
# file dog.4495.jpg is: cat
# file dog.4496.jpg is: cat
# file dog.4497.jpg is: cat
# file dog.4498.jpg is: cat
# file dog.4499.jpg is: cat
# file dog.4500.jpg is: cat
# file dog.4501.jpg is: cat
# file dog.4502.jpg is: cat
# file dog.4503.jpg is: cat
# file dog.4504.jpg is: cat
# file dog.4505.jpg is: cat
# file dog.4506.jpg is: cat
# file dog.4507.jpg is: cat
# file dog.4508.jpg is: cat
# file dog.4509.jpg is: cat
# file dog.4510.jpg is: gorilla
# file dog.4511.jpg is: cat
# file dog.4512.jpg is: cat
# file dog.4513.jpg is: cat
# file dog.4514.jpg is: cat
# file dog.4515.jpg is: gorilla
# file dog.4516.jpg is: cat
# file dog.4517.jpg is: cat
# file dog.4518.jpg is: cat
# file dog.4519.jpg is: cat
# file dog.4520.jpg is: gorilla
# file dog.4521.jpg is: cat
# file dog.4522.jpg is: cat
# file dog.4523.jpg is: cat
# file dog.4524.jpg is: cat
# file dog.4525.jpg is: cat
# file dog.4526.jpg is: cat
# file dog.4527.jpg is: cat
# file dog.4528.jpg is: cat
# file dog.4529.jpg is: cat
# file dog.4530.jpg is: cat
# file dog.4531.jpg is: cat
# file dog.4532.jpg is: cat
# file dog.4533.jpg is: cat
# file dog.4534.jpg is: cat
# file dog.4535.jpg is: cat
# file dog.4536.jpg is: cat
# file dog.4537.jpg is: gorilla
# file dog.4538.jpg is: cat
# file dog.4539.jpg is: cat
# file dog.4540.jpg is: cat
# file dog.4541.jpg is: cat
# file dog.4542.jpg is: cat
# file dog.4543.jpg is: cat
# file dog.4544.jpg is: cat
# file dog.4545.jpg is: cat
# file dog.4546.jpg is: cat
# file dog.4547.jpg is: gorilla
# file dog.4548.jpg is: cat
# file dog.4549.jpg is: cat
# file dog.4550.jpg is: cat
# file dog.4551.jpg is: cat
# file dog.4552.jpg is: cat
# file dog.4553.jpg is: cat
# file dog.4554.jpg is: cat
# file dog.4555.jpg is: cat
# file dog.4556.jpg is: gorilla
# file dog.4557.jpg is: cat
# file dog.4558.jpg is: cat
# file dog.4559.jpg is: cat
# file dog.4560.jpg is: cat
# file dog.4561.jpg is: cat
# file dog.4562.jpg is: cat
# file dog.4563(1).jpg is: cat
# file dog.4563.jpg is: cat
# file dog.4564.jpg is: cat
# file dog.4565.jpg is: cat
# file dog.4566.jpg is: cat
# file dog.4567.jpg is: cat
# file dog.4568.jpg is: cat
# file dog.4569.jpg is: cat
# file dog.4570.jpg is: cat
# file dog.4571.jpg is: cat
# file dog.4572.jpg is: gorilla
# file dog.4573.jpg is: cat
# file dog.4574.jpg is: cat
# file dog.4575.jpg is: cat
# file dog.4576.jpg is: cat
# file dog.4577.jpg is: cat
# file dog.4578.jpg is: cat
# file dog.4579.jpg is: cat
# file dog.4580.jpg is: cat
# file dog.4581.jpg is: cat
# file dog.4582.jpg is: cat
# file dog.4583.jpg is: cat
# file dog.4584.jpg is: cat
# file dog.4585.jpg is: cat
# file dog.4586.jpg is: cat
# file dog.4587.jpg is: cat
# file dog.4588.jpg is: cat
# file dog.4589.jpg is: cat
# file dog.4590.jpg is: cat
# file dog.4591.jpg is: cat
# file dog.4592.jpg is: cat
# file dog.4593.jpg is: cat
# file dog.4594.jpg is: cat
# file dog.4595.jpg is: gorilla
# file dog.4596.jpg is: cat
# file dog.4597.jpg is: cat
# file dog.4598.jpg is: cat
# file dog.4599.jpg is: cat
# file dog.4600.jpg is: cat
# file dog.4601.jpg is: cat
# file dog.4602.jpg is: cat
# file dog.4603(1).jpg is: cat
# file dog.4603.jpg is: cat
# file dog.4604.jpg is: cat
# file dog.4605.jpg is: cat
# file dog.4606.jpg is: cat
# file dog.4607.jpg is: gorilla
# file dog.4608.jpg is: cat
# file dog.4609.jpg is: cat
# file dog.4610.jpg is: cat
# file dog.4611.jpg is: cat
# file dog.4612.jpg is: cat
# file dog.4613.jpg is: cat
# file dog.4614.jpg is: cat
# file dog.4615.jpg is: cat
# file dog.4616.jpg is: cat
# file dog.4617(1).jpg is: cat
# file dog.4617.jpg is: cat
# file dog.4618.jpg is: cat
# file dog.4619.jpg is: cat
# file dog.4620.jpg is: cat
# file dog.4621.jpg is: cat
# file dog.4622.jpg is: cat
# file dog.4623.jpg is: cat
# file dog.4624.jpg is: cat
# file dog.4625.jpg is: cat
# file dog.4626.jpg is: cat
# file dog.4627.jpg is: cat
# file dog.4628.jpg is: cat
# file dog.4629.jpg is: cat
# file dog.4630.jpg is: cat
# file dog.4631.jpg is: cat
# file dog.4632.jpg is: cat
# file dog.4633.jpg is: cat
# file dog.4634.jpg is: cat
# file dog.4635.jpg is: cat
# file dog.4636.jpg is: cat
# file dog.4637.jpg is: cat
# file dog.4638.jpg is: cat
# file dog.4639.jpg is: cat
# file dog.4640.jpg is: cat
# file dog.4641.jpg is: cat
# file dog.4642.jpg is: cat
# file dog.4643.jpg is: cat
# file dog.4644.jpg is: cat
# file dog.4645.jpg is: cat
# file dog.4646.jpg is: cat
# file dog.4647.jpg is: cat
# file dog.4648.jpg is: cat
# file dog.4649.jpg is: cat
# file dog.4650.jpg is: cat
# file dog.4651.jpg is: cat
# file dog.4652.jpg is: cat
# file dog.4653.jpg is: cat
# file dog.4654.jpg is: cat
# file dog.4655.jpg is: cat
# file dog.4656.jpg is: cat
# file dog.4657.jpg is: cat
# file dog.4658.jpg is: cat
# file dog.4659.jpg is: cat
# file dog.4660.jpg is: cat
# file dog.4661.jpg is: cat
# file dog.4662.jpg is: gorilla
# file dog.4663.jpg is: cat
# file dog.4664.jpg is: cat
# file dog.4665.jpg is: cat
# file dog.4666.jpg is: gorilla
# file dog.4667.jpg is: cat
# file dog.4668.jpg is: cat
# file dog.4669.jpg is: cat
# file dog.4670.jpg is: cat
# file dog.4671.jpg is: cat
# file dog.4672.jpg is: cat
# file dog.4673.jpg is: cat
# file dog.4674.jpg is: cat
# file dog.4675.jpg is: cat
# file dog.4676.jpg is: cat
# file dog.4677.jpg is: cat
# file dog.4678.jpg is: cat
# file dog.4679.jpg is: cat
# file dog.4680.jpg is: cat
# file dog.4681.jpg is: cat
# file dog.4682.jpg is: cat
# file dog.4683.jpg is: cat
# file dog.4684.jpg is: gorilla
# file dog.4685.jpg is: gorilla
# file dog.4686.jpg is: gorilla
# file dog.4687.jpg is: cat
# file dog.4688.jpg is: cat
# file dog.4689.jpg is: cat
# file dog.4690.jpg is: cat
# file dog.4691.jpg is: cat
# file dog.4692.jpg is: cat
# file dog.4693.jpg is: cat
# file dog.4694.jpg is: cat
# file dog.4695.jpg is: cat
# file dog.4696.jpg is: cat
# file dog.4697.jpg is: cat
# file dog.4698.jpg is: cat
# file dog.4699.jpg is: cat
# file dog.4700.jpg is: cat
# file dog.4701.jpg is: cat
# file dog.4702.jpg is: cat
# file dog.4703.jpg is: cat
# file dog.4704.jpg is: cat
# file dog.4705.jpg is: cat
# file dog.4706.jpg is: cat
# file dog.4707.jpg is: cat
# file dog.4708.jpg is: cat
# file dog.4709.jpg is: cat
# file dog.4710.jpg is: cat
# file dog.4711.jpg is: cat
# file dog.4712.jpg is: cat
# file dog.4713.jpg is: cat
# file dog.4714.jpg is: cat
# file dog.4715.jpg is: cat
# file dog.4716.jpg is: cat
# file dog.4717.jpg is: cat
# file dog.4718.jpg is: cat
# file dog.4719.jpg is: cat
# file dog.4720.jpg is: cat
# file dog.4721.jpg is: cat
# file dog.4722.jpg is: cat
# file dog.4723.jpg is: cat
# file dog.4724.jpg is: cat
# file dog.4725.jpg is: cat
# file dog.4726.jpg is: cat
# file dog.4727.jpg is: cat
# file dog.4728.jpg is: cat
# file dog.4729.jpg is: cat
# file dog.4730.jpg is: cat
# file dog.4731.jpg is: gorilla
# file dog.4732.jpg is: cat
# file dog.4733.jpg is: cat
# file dog.4734.jpg is: cat
# file dog.4735.jpg is: cat
# file dog.4736.jpg is: cat
# file dog.4737.jpg is: gorilla
# file dog.4738.jpg is: cat
# file dog.4739.jpg is: cat
# file dog.4740.jpg is: cat
# file dog.4741.jpg is: cat
# file dog.4742.jpg is: gorilla
# file dog.4743.jpg is: cat
# file dog.4744.jpg is: cat
# file dog.4745.jpg is: cat
# file dog.4746.jpg is: cat
# file dog.4747.jpg is: cat
# file dog.4748.jpg is: cat
# file dog.4749.jpg is: cat
# file dog.4750.jpg is: cat
# file dog.4751.jpg is: cat
# file dog.4752.jpg is: cat
# file dog.4753.jpg is: cat
# file dog.4754.jpg is: cat
# file dog.4755.jpg is: cat
# file dog.4756.jpg is: cat
# file dog.4757.jpg is: cat
# file dog.4758.jpg is: cat
# file dog.4759.jpg is: cat
# file dog.4760.jpg is: cat
# file dog.4761.jpg is: cat
# file dog.4762.jpg is: cat
# file dog.4763.jpg is: cat
# file dog.4764.jpg is: cat
# file dog.4765.jpg is: cat
# file dog.4766.jpg is: cat
# file dog.4767.jpg is: cat
# file dog.4768.jpg is: cat
# file dog.4769.jpg is: cat
# file dog.4770.jpg is: cat
# file dog.4771.jpg is: cat
# file dog.4772.jpg is: gorilla
# file dog.4773.jpg is: cat
# file dog.4774.jpg is: cat
# file dog.4775.jpg is: cat
# file dog.4776.jpg is: cat
# file dog.4777.jpg is: cat
# file dog.4778.jpg is: cat
# file dog.4779.jpg is: cat
# file dog.4780.jpg is: cat
# file dog.4781.jpg is: cat
# file dog.4782.jpg is: cat
# file dog.4783.jpg is: cat
# file dog.4784.jpg is: cat
# file dog.4785.jpg is: cat
# file dog.4786.jpg is: cat
# file dog.4787.jpg is: cat
# file dog.4788.jpg is: cat
# file dog.4789.jpg is: cat
# file dog.4790.jpg is: cat
# file dog.4791.jpg is: cat
# file dog.4792.jpg is: cat
# file dog.4793.jpg is: gorilla
# file dog.4794.jpg is: cat
# file dog.4795.jpg is: cat
# file dog.4796.jpg is: cat
# file dog.4797.jpg is: cat
# file dog.4798.jpg is: cat
# file dog.4799.jpg is: cat
# file dog.4800.jpg is: cat
# file dog.4801.jpg is: cat
# file dog.4802.jpg is: gorilla
# file dog.4803.jpg is: cat
# file dog.4804.jpg is: cat
# file dog.4805.jpg is: cat
# file dog.4806.jpg is: cat
# file dog.4807.jpg is: cat
# file dog.4808.jpg is: cat
# file dog.4809.jpg is: cat
# file dog.4810.jpg is: cat
# file dog.4811.jpg is: cat
# file dog.4812.jpg is: cat
# file dog.4813.jpg is: cat
# file dog.4814.jpg is: cat
# file dog.4815.jpg is: cat
# file dog.4816.jpg is: gorilla
# file dog.4817.jpg is: cat
# file dog.4818(1).jpg is: cat
# file dog.4818.jpg is: cat
# file dog.4819.jpg is: gorilla
# file dog.4820.jpg is: cat
# file dog.4821.jpg is: cat
# file dog.4822.jpg is: cat
# file dog.4823.jpg is: cat
# file dog.4824(1).jpg is: cat
# file dog.4824.jpg is: cat
# file dog.4825.jpg is: gorilla
# file dog.4826.jpg is: cat
# file dog.4827.jpg is: cat
# file dog.4828.jpg is: cat
# file dog.4829.jpg is: cat
# file dog.4830(1).jpg is: cat
# file dog.4830.jpg is: cat
# file dog.4831.jpg is: cat
# file dog.4832.jpg is: cat
# file dog.4833.jpg is: cat
# file dog.4834.jpg is: cat
# file dog.4835.jpg is: cat
# file dog.4836.jpg is: cat
# file dog.4837.jpg is: cat
# file dog.4838.jpg is: cat
# file dog.4839.jpg is: cat
# file dog.4840.jpg is: cat
# file dog.4841.jpg is: cat
# file dog.4842.jpg is: cat
# file dog.4843.jpg is: cat
# file dog.4844.jpg is: cat
# file dog.4845.jpg is: cat
# file dog.4846.jpg is: gorilla
# file dog.4847.jpg is: cat
# file dog.4848.jpg is: cat
# file dog.4849.jpg is: cat
# file dog.4850.jpg is: cat
# file dog.4851.jpg is: cat
# file dog.4852.jpg is: cat
# file dog.4853.jpg is: cat
# file dog.4854.jpg is: cat
# file dog.4855.jpg is: cat
# file dog.4856.jpg is: cat
# file dog.4857.jpg is: cat
# file dog.4858.jpg is: cat
# file dog.4859.jpg is: cat
# file dog.4860.jpg is: cat
# file dog.4861.jpg is: cat
# file dog.4862.jpg is: cat
# file dog.4863.jpg is: cat
# file dog.4864.jpg is: cat
# file dog.4865.jpg is: cat
# file dog.4866.jpg is: cat
# file dog.4867.jpg is: cat
# file dog.4868.jpg is: cat
# file dog.4869.jpg is: cat
# file dog.4870.jpg is: cat
# file dog.4871.jpg is: cat
# file dog.4872.jpg is: cat
# file dog.4873.jpg is: cat
# file dog.4874.jpg is: cat
# file dog.4875.jpg is: gorilla
# file dog.4876.jpg is: cat
# file dog.4877.jpg is: gorilla
# file dog.4878.jpg is: cat
# file dog.4879.jpg is: gorilla
# file dog.4880.jpg is: cat
# file dog.4881.jpg is: cat
# file dog.4882.jpg is: cat
# file dog.4883.jpg is: cat
# file dog.4884.jpg is: gorilla
# file dog.4885.jpg is: cat
# file dog.4886.jpg is: cat
# file dog.4887.jpg is: cat
# file dog.4888.jpg is: gorilla
# file dog.4889.jpg is: cat
# file dog.4890.jpg is: cat
# file dog.4891.jpg is: cat
# file dog.4892.jpg is: cat
# file dog.4893.jpg is: cat
# file dog.4894.jpg is: gorilla
# file dog.4895.jpg is: cat
# file dog.4896.jpg is: cat
# file dog.4897.jpg is: cat
# file dog.4898.jpg is: cat
# file dog.4899.jpg is: cat
# file dog.4900.jpg is: cat
# file dog.4901.jpg is: cat
# file dog.4902.jpg is: gorilla
# file dog.4903.jpg is: cat
# file dog.4904.jpg is: cat
# file dog.4905.jpg is: cat
# file dog.4906.jpg is: cat
# file dog.4907.jpg is: cat
# file dog.4908.jpg is: cat
# file dog.4909.jpg is: cat
# file dog.4910.jpg is: cat
# file dog.4911.jpg is: cat
# file dog.4912.jpg is: cat
# file dog.4913.jpg is: cat
# file dog.4914.jpg is: cat
# file dog.4915.jpg is: cat
# file dog.4916.jpg is: cat
# file dog.4917.jpg is: cat
# file dog.4918.jpg is: cat
# file dog.4919.jpg is: cat
# file dog.4920.jpg is: cat
# file dog.4921.jpg is: cat
# file dog.4922.jpg is: cat
# file dog.4923.jpg is: cat
# file dog.4924.jpg is: cat
# file dog.4925.jpg is: cat
# file dog.4926.jpg is: cat
# file dog.4927.jpg is: cat
# file dog.4928.jpg is: cat
# file dog.4929.jpg is: cat
# file dog.4930.jpg is: cat
# file dog.4931.jpg is: cat
# file dog.4932.jpg is: cat
# file dog.4933.jpg is: cat
# file dog.4934.jpg is: cat
# file dog.4935.jpg is: cat
# file dog.4936.jpg is: cat
# file dog.4937.jpg is: cat
# file dog.4938.jpg is: cat
# file dog.4939.jpg is: cat
# file dog.4940.jpg is: cat
# file dog.4941.jpg is: cat
# file dog.4942.jpg is: cat
# file dog.4943.jpg is: cat
# file dog.4944.jpg is: cat
# file dog.4945.jpg is: cat
# file dog.4946.jpg is: cat
# file dog.4947.jpg is: cat
# file dog.4948.jpg is: gorilla
# file dog.4949.jpg is: cat
# file dog.4950.jpg is: cat
# file dog.4951.jpg is: cat
# file dog.4952.jpg is: cat
# file dog.4953.jpg is: cat
# file dog.4954.jpg is: cat
# file dog.4955.jpg is: cat
# file dog.4956.jpg is: cat
# file dog.4957.jpg is: cat
# file dog.4958.jpg is: cat
# file dog.4959.jpg is: cat
# file dog.4960.jpg is: gorilla
# file dog.4961.jpg is: cat
# file dog.4962.jpg is: cat
# file dog.4963.jpg is: cat
# file dog.4964.jpg is: cat
# file dog.4965.jpg is: cat
# file dog.4966.jpg is: cat
# file dog.4967.jpg is: cat
# file dog.4968.jpg is: cat
# file dog.4969.jpg is: cat
# file dog.4970.jpg is: cat
# file dog.4971.jpg is: cat
# file dog.4972.jpg is: cat
# file dog.4973.jpg is: cat
# file dog.4974.jpg is: cat
# file dog.4975.jpg is: cat
# file dog.4976.jpg is: cat
# file dog.4977.jpg is: cat
# file dog.4978.jpg is: cat
# file dog.4979.jpg is: cat
# file dog.4980.jpg is: cat
# file dog.4981.jpg is: cat
# file dog.4982.jpg is: cat
# file dog.4983.jpg is: cat
# file dog.4984.jpg is: cat
# file dog.4985.jpg is: cat
# file dog.4986.jpg is: cat
# file dog.4987.jpg is: cat
# file dog.4988.jpg is: cat
# file dog.4989.jpg is: cat
# file dog.4990.jpg is: cat
# file dog.4991.jpg is: cat
# file dog.4992.jpg is: cat
# file dog.4993.jpg is: cat
# file dog.4994.jpg is: cat
# file dog.4995.jpg is: cat
# file dog.4996.jpg is: cat
# file dog.4997.jpg is: cat
# file dog.4998.jpg is: cat
# file dog.4999.jpg is: gorilla
# file dog.5000.jpg is: cat
